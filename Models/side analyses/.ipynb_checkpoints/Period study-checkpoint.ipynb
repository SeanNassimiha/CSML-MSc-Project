# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import pandas as pd

# %%
data_multiple =  pd.read_csv('../../../Data/pv_power_df_5day_capacity_scaled.csv', index_col='datetime').drop(columns=['2657', '2828']) #DROPPING FAULTY SYSTEMS
uk_pv = pd.read_csv('../../../Data/system_metadata_location_rounded.csv')
uk_pv['ss_id_string'] = uk_pv['ss_id'].astype('str')

# %%
data_multiple.iloc[:,:5].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
from scipy.optimize import leastsq

t = np.arange(len(data))
data = data_multiple.iloc[:,0]
guess_mean = np.mean(data)
guess_std = np.std(data)
guess_phase = 0
freq = 1 / (97 * 365.25)
guess_amp = 0.5

# we'll use this to plot our first estimate. This might already be good enough for you
data_first_guess = guess_std*np.sin(freq*t+guess_phase) + guess_mean

# Define the function to optimize, in this case, we want to minimize the difference
# between the actual data and our "guessed" parameters
optimize_func = lambda x: x[0]*np.sin(freq*t+x[1]) + x[2] - data
est_amp, est_phase, est_mean = leastsq(optimize_func, [guess_amp, guess_phase, guess_mean])[0]

# recreate the fitted curve using the optimized parameters
data_fit = est_amp*np.sin(freq*t+est_phase) + est_mean

# recreate the fitted curve using the optimized parameters

fine_t = np.arange(0,max(t),0.1)
data_fit=est_amp*np.sin(freq*fine_t+est_phase)+est_mean

plt.plot(t, data, '.')
plt.plot(t, data_first_guess, label='first guess')
plt.plot(fine_t, data_fit, label='after fitting')
plt.legend()
plt.show()

# %%
# we'll use this to plot our first estimate. This might already be good enough for you
data_first_guess = 0.3*np.sin(5 * freq*t) + 0.4

plt.plot(t, data, '.')
plt.plot(t, data_first_guess, label='first guess')

# %% [markdown]
# # Try with the Weigthing method

# %%
data = data_multiple.iloc[:,0:1]
data.rolling(window=97*60).mean().idxmax()
# Out:
# 2607    2018-08-08 13:25:00
# dtype: object

# %%
Fs = len(data)
y = data.values[:,0]
t = np.arange(0,1,1/Fs)
# Perform Fourier transform using scipy
from scipy import fftpack
y_fft = fftpack.fft(y)
# Plot data
n = np.size(t)
fr = Fs/2 * np.linspace(0,1,int(n/2))
y_m = 2/n * abs(y_fft[0:np.size(fr)])
fig, ax = plt.subplots(nrows=1, ncols=2, figsize=(15,5))
ax[0].plot(t, y)    # plot time series
ax[1].stem(fr, y_m) # plot freq domain
# Out:
# <StemContainer object of 3 artists>

# %%
plt.plot(y_fft)
# Out:
# /Users/SeanNassimiha/miniforge3/envs/mscjax_dev/lib/python3.8/site-packages/matplotlib/cbook/__init__.py:1298: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %% [markdown]
# # Try with fourier

# %%
def fourier_series_coeff_numpy(f, T, N, return_complex=False):
    """Calculates the first 2*N+1 Fourier series coeff. of a periodic function.

    Given a periodic, function f(t) with period T, this function returns the
    coefficients a0, {a1,a2,...},{b1,b2,...} such that:

    f(t) ~= a0/2+ sum_{k=1}^{N} ( a_k*cos(2*pi*k*t/T) + b_k*sin(2*pi*k*t/T) )

    If return_complex is set to True, it returns instead the coefficients
    {c0,c1,c2,...}
    such that:

    f(t) ~= sum_{k=-N}^{N} c_k * exp(i*2*pi*k*t/T)

    where we define c_{-n} = complex_conjugate(c_{n})

    Refer to wikipedia for the relation between the real-valued and complex
    valued coeffs at http://en.wikipedia.org/wiki/Fourier_series.

    Parameters
    ----------
    f : the periodic function, a callable like f(t)
    T : the period of the function f, so that f(0)==f(T)
    N_max : the function will return the first N_max + 1 Fourier coeff.

    Returns
    -------
    if return_complex == False, the function returns:

    a0 : float
    a,b : numpy float arrays describing respectively the cosine and sine coeff.

    if return_complex == True, the function returns:

    c : numpy 1-dimensional complex-valued array of size N+1

    """
    # From Shanon theoreom we must use a sampling freq. larger than the maximum
    # frequency you want to catch in the signal.
    f_sample = 2 * N
    # we also need to use an integer sampling frequency, or the
    # points will not be equispaced between 0 and 1. We then add +2 to f_sample
    t, dt = np.linspace(0, T, f_sample + 2, endpoint=False, retstep=True)

    y = np.fft.rfft(f(t)) / t.size

    if return_complex:
        return y
    else:
        y *= 2
        return y[0].real, y[1:-1].real, -y[1:-1].imag

# %%
N = 3

f_sample = 2 * N
# we also need to use an integer sampling frequency, or the
# points will not be equispaced between 0 and 1. We then add +2 to f_sample
t, dt = np.linspace(0, 97*365, f_sample + 2, endpoint=False, retstep=True)

# %%
def get_divisors(n):
    for i in range(1, int(n / 2) + 1):
        if n % i == 0:
            print(i)
    print(n)

# %%
get_divisors(97*365)
# Out:
# 1
# 5
# 73
# 97
# 365
# 485
# 7081
# 35405

# %%
97*365 /
# Out:
# 2723.4615384615386

# %%
def fun_data(t):
    return data[t]

# %%
data = data_multiple.iloc[:,0]
t = np.arange(len(data))

# %%
coeffs = fourier_series_coeff_numpy(fun_data, 97*365, 3, return_complex=False)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [40], in <module>
# ----> 1 coeffs = fourier_series_coeff_numpy(fun_data, 97*365, 3, return_complex=False)
#
# Input In [4], in fourier_series_coeff_numpy(f, T, N, return_complex)
#      41 # we also need to use an integer sampling frequency, or the
#      42 # points will not be equispaced between 0 and 1. We then add +2 to f_sample
#      43 t, dt = np.linspace(0, T, f_sample + 2, endpoint=False, retstep=True)
# ---> 45 y = np.fft.rfft(f(t)) / t.size
#      47 if return_complex:
#      48     return y
#
# Input In [21], in fun_data(t)
#       1 def fun_data(t):
# ----> 2     return data[t]
#
# File ~/miniforge3/envs/mscjax_dev/lib/python3.8/site-packages/pandas/core/series.py:985, in Series.__getitem__(self, key)
#     982     key = np.asarray(key, dtype=bool)
#     983     return self._get_values(key)
# ...

# %%
coeffs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <module>
# ----> 1 coeffs
#
# NameError: name 'coeffs' is not defined
