# %% [markdown]
# # Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import gpflow
from gpflow.utilities import print_summary
import time
print(gpflow.__version__)
# Out:
# /Users/SeanNassimiha/miniforge3/envs/mscproject/lib/python3.8/site-packages/jax/_src/lib/__init__.py:33: UserWarning: JAX on Mac ARM machines is experimental and minimally tested. Please see https://github.com/google/jax/issues/5501 in the event of problems.
#   warnings.warn("JAX on Mac ARM machines is experimental and minimally tested. "
# 2.3.1

# %%
# data =  pd.read_csv('/content/drive/MyDrive/Data_MSC/pv_power_df_5day.csv', index_col='datetime')
# data_val = pd.read_csv('/content/drive/MyDrive/Data_MSC/pv_power_df_5day_validation.csv', index_col='datetime')
# uk_pv = pd.read_csv('/content/drive/MyDrive/Data_MSC/UK_PV_metadata.csv')

data =  pd.read_csv('Data/pv_power_df_5day.csv', index_col='datetime')
data_val = pd.read_csv('Data/pv_power_df_5day_validation.csv', index_col='datetime')

data_val = pd.read_csv('Data/pv_power_df_5day_validation.csv', index_col='datetime')
uk_pv = pd.read_csv('Data/system_metadata_location_rounded.csv')

# %%
data.iloc[:,1].plot()
plt.show()
data_val.iloc[:,1].plot()
# Out:
# <AxesSubplot:xlabel='datetime'>

# %%
data.iloc[:,1]['2018-01-02': '2018-01-03'].plot()
pd.plotting.autocorrelation_plot(data.iloc[:,0])
pd.plotting.autocorrelation_plot(data.iloc[:,2])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %% [markdown]
# ## Nest steps:
#
# 1. Decide what to do with missing values in time series
# 2. Remove seasonality
# 3. correlation plots
# 4. define distance between solar farms (possible I can start with a model that assume independency
